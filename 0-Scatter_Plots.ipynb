# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("dm_office_sales.csv")

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   division            1000 non-null   object
#  1   level of education  1000 non-null   object
#  2   training level      1000 non-null   int64
#  3   work experience     1000 non-null   int64
#  4   salary              1000 non-null   int64
#  5   sales               1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
# setting up the chart size and background
plt.rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')

# for Interactive Shells
from IPython.display import display

# %% [markdown]
# # Scatterplot

# %%
sns.scatterplot(x='salary',y='sales',data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# It shows a linear Relationship that means if a salary of a person increases then sales will also increase

# %% [markdown]
# ## Seaborn Parameters
#
# The hue and palette parameters are commonly available around many plot calls in seaborn.
#
# ### hue
#
# Color points based off a categorical feature in the DataFrame

# %%
#Lets take hue--->work experiance

sns.scatterplot(x='salary',y='sales',hue='work experience', data=df, palette='Set2')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary',y='sales',data=df,hue='division',alpha=0.8, palette='deep')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# **Choosing a palette from Matplotlib's cmap: https://matplotlib.org/tutorials/colors/colormaps.html**
#
# we can choose various palette, for example:

# %%
sns.scatterplot(x='salary',y='sales',data=df,hue='work experience',palette='viridis')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary',y='sales',data=df,hue='work experience',palette='magma')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ## Scatterplot  Parameters
#
# These parameters are more specific to the scatterplot() call
#
# ### size
#
# Allows us to size based on another column

# %%
sns.scatterplot(x='salary',y='sales',data=df,size='work experience',palette='pastel1')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# **Use *s=* if you want to change the marker size to be some uniform integer value**

# %%
sns.scatterplot(x='salary',y='sales',data=df,s=200)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary',y='sales',data=df,s=200,linewidth=0,alpha=0.2)   #alpha is used for opacity
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ### style
#
# Automatically choose styles based on another categorical feature in the dataset. Optionally use the **markers=** parameter to pass a list of marker choices based off matplotlib, for example: ['*','+','o']

# %%
sns.scatterplot(x='salary',y='sales',data=df,style='level of education')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
# Sometimes its nice to do BOTH hue and style off the same column
sns.scatterplot(x='salary',y='sales',data=df,style='level of education',hue='level of education',s=100)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(x='salary',y='sales',data=df,style='level of education',hue='division',s=50)

plt.legend(bbox_to_anchor=[0.1,0.4])

# %%
sns.scatterplot(
    data=df, x="salary", y="sales", hue="training level", size="training level",
    sizes=(20, 200), hue_norm=(0, 7), legend="full"
)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
sns.scatterplot(data=df, x="work experience", y="sales", s=100, color=".2", marker="+")
# Out:
# <AxesSubplot:xlabel='work experience', ylabel='sales'>

# %% [markdown]
# ### 3D plot

# %% [markdown]
# ![3d plot](https://stackabuse.s3.amazonaws.com/media/seaborn-scatter-plot-tutorial-and-examples-3.gif)

# %% [markdown]
# Seaborn doesn't come with any built-in 3D functionality, unfortunately. It's an extension of Matplotlib and relies on it for the heavy lifting in 3D. Though, we can style the 3D Matplotlib plot, using Seaborn.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = df['salary']
y = df['sales']
z = df['training level']

ax.set_xlabel("salary")
ax.set_ylabel("sales")
ax.set_zlabel("training level")

ax.scatter(x, y, z)

plt.show()

# %% [markdown]
# ### Exporting a Seaborn Figure
#
# we can save the the plot locally

# %%
plt.figure(figsize=(14,8))

sns.scatterplot(x='salary',y='sales',data=df,style='level of education',hue='level of education',s=100)

# Call savefig in the same cell
plt.savefig('example_scatter.jpg')
